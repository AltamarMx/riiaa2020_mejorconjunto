# %%
import pandas as pd
import matplotlib.pyplot as plt
from dateutil.parser import parse

# %%
archivo = '../data/metrics/todos.csv'
datos = pd.read_csv(archivo,index_col=0,parse_dates=True)
datos.head()
# Out:
#                          Ti_ae      Ti_bm      Ti_ca      Ti_za         Ti  \
# tiempo
# 2019-06-09 00:10:00  26.665128  26.821598  26.882885  26.725280  26.900937
# 2019-06-09 00:20:00  26.649338  26.792661  26.733839  26.705504  26.905551
# 2019-06-09 00:30:00  26.584348  26.757332  26.681603  26.645700  26.800565
# 2019-06-09 00:40:00  26.356539  26.694438  26.646719  26.535329  26.730189
# 2019-06-09 00:50:00  26.232836  26.639742  26.563872  26.493954  26.664428
#
#                      To_esolmet
# tiempo
# 2019-06-09 00:10:00       23.52
# 2019-06-09 00:20:00       23.75
# 2019-06-09 00:30:00       23.74
# 2019-06-09 00:40:00       23.55
# 2019-06-09 00:50:00       23.66

# %%
fig, ax = plt.subplots(figsize=(18,7))

fecha1 = parse("2019-06-22")
fecha2 = fecha1 + pd.Timedelta("2D")

ax.set_xlim(fecha1,fecha2)


ax.plot(datos.Ti_ae,'r+')
ax.plot(datos.Ti_bm,'g+')
ax.plot(datos.Ti_ca,'b+')
ax.plot(datos.Ti_za,'y+')

ax.plot(datos.Ti,'k-',linewidth=4)

# %%
datos
